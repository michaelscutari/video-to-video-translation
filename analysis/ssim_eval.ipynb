# %%
from ssim2 import *
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from ssim2 import *
#
# File ~/Desktop/ECE 661/Project 661/ece661-GAN-project/analysis/ssim2.py:166
#     162 #### HOW TO USE ##################################################
#     164 folder_path = 'cycle_pix_maps_compared'
# --> 166 ssim_scores_pix2pix, ssim_scores_cycle = evaluate_folder_ssim(folder_path, plotScores=True)
#
# File ~/Desktop/ECE 661/Project 661/ece661-GAN-project/analysis/ssim2.py:118, in evaluate_folder_ssim(folder_path, WINDOW_SIZE, ALPHA_chosen, BETA_chosen, GAMMA_chosen, plotAll, plotScores)
#     109 def evaluate_folder_ssim(folder_path,
#     110                     WINDOW_SIZE=None,
#     111                     ALPHA_chosen=None,BETA_chosen=None, GAMMA_chosen=None,
#    (...)
#     116
#     117     # find all images with a name containing 'real'
# --> 118     real_images = [fileName for fileName in os.listdir(folder_path) if 'real' in fileName]
#     119     real_images.sort()
#     121     # find all images with a name containing 'cycle'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cycle_pix_maps_compared'

# %%
folder_path = 'analysis/cycle_pix_maps_compared'

ssim_scores_pix2pix, ssim_scores_cycle = evaluate_folder_ssim(folder_path, plotScores=True)
